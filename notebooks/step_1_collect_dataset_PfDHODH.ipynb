# %% [markdown]
# ### __1. Data acquisition__
#
# This notebook focuses on acquiring data for the Malaria Plasmodium falciparum dihydroorotate dehydrogenase (PfDHODH) drug target from ChEMBL. Using Python libraries like pandas, NumPy, and RDKit, I will manipulate and analyze the data, such as filtering and potentially feature engineering in the future. The code utilizes chembl_webresource_client.new_client to directly access bioactivity data for PfDHODH from the ChEMBL database.
#
# First, import necessary libraries and modules to search for the PfDHODH target and its associated compounds dataset in ChEMBL.

# %%
import pandas as pd # For data manipulation and analysis
import numpy as np # For numerical operations
from chembl_webresource_client.new_client import new_client # For accessing ChEMBL database
from rdkit.Chem import PandasTools # For handling chemical structures
from zipfile import ZipFile # For handling zip files

# %% [markdown]
# ##### __1.1 Search for the target, PfDHODH, in ChEMBL__

# %%
target_protein = new_client.target # For accessing target in ChEMBL
target_query = target_protein.search('Dihydroorotate dehydrogenase').filter(target_type='SINGLE PROTEIN').filter(organism='Plasmodium falciparum') # Querying the target
target_query # Displaying the data which in this case is a dictionary
# Out:
# [{'cross_references': [{'xref_id': 'Q54A96', 'xref_name': None, 'xref_src': 'canSAR-Target'}], 'organism': 'Plasmodium falciparum', 'pref_name': 'Dihydroorotate dehydrogenase', 'score': 24.0, 'species_group_flag': False, 'target_chembl_id': 'CHEMBL3486', 'target_components': [{'accession': 'Q54A96', 'component_description': 'Dihydroorotate dehydrogenase (quinone), mitochondrial', 'component_id': 1807, 'component_type': 'PROTEIN', 'relationship': 'SINGLE PROTEIN', 'target_component_synonyms': [{'component_synonym': 'dhod', 'syn_type': 'GENE_SYMBOL'}, {'component_synonym': 'Dihydroorotate dehydrogenase (quinone), mitochondrial', 'syn_type': 'UNIPROT'}, {'component_synonym': '1.3.5.2', 'syn_type': 'EC_NUMBER'}], 'target_component_xrefs': [{'xref_id': 'GO:0005737', 'xref_name': 'cytoplasm', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0005743', 'xref_name': 'mitochondrial inner membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0005886', 'xref_name': 'plasma membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0016020', 'xref_name': 'membrane', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0000166', 'xref_name': 'nucleotide binding', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0004152', 'xref_name': 'dihydroorotate dehydrogenase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0016491', 'xref_name': 'oxidoreductase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0016627', 'xref_name': 'oxidoreductase activity, acting on the CH-CH group of donors', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0106430', 'xref_name': 'dihydroorotate dehydrogenase (quinone) activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0006207', 'xref_name': "'de novo' pyrimidine nucleobase biosynthetic process", 'xref_src_db': 'GoProcess'}, {'xref_id': 'GO:0009220', 'xref_name': 'pyrimidine ribonucleotide biosynthetic process', 'xref_src_db': 'GoProcess'}, {'xref_id': 'GO:0044205', 'xref_name': "'de novo' UMP biosynthetic process", 'xref_src_db': 'GoProcess'}, {'xref_id': 'IPR001295', 'xref_name': 'Dihydroorotate_DH_CS.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR005719', 'xref_name': 'Dihydroorotate_DH_2.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR005720', 'xref_name': 'Dihydroorotate_DH_dom.', 'xref_src_db': 'InterPro'}, {'xref_id': 'IPR013785', 'xref_name': 'Aldolase_TIM.', 'xref_src_db': 'InterPro'}, {'xref_id': '6I55', 'xref_name': 'A', 'xref_src_db': 'PDBe'}, {'xref_id': 'PF01180', 'xref_name': 'DHO_dh', 'xref_src_db': 'Pfam'}, {'xref_id': 'Q54A96', 'xref_name': None, 'xref_src_db': 'UniProt'}]}], 'target_type': 'SINGLE PROTEIN', 'tax_id': 5833}, {'cross_references': [{'xref_id': 'Q6KCB6', 'xref_name': None, 'xref_src': 'canSAR-Target'}], 'organism': 'Plasmodium falciparum', 'pref_name': 'Dihydrolipoyl dehydrogenase', 'score': 9.0, 'species_group_flag': False, 'target_chembl_id': 'CHEMBL6147', 'target_components': [{'accession': 'Q6KCB6', 'component_description': 'Dihydrolipoyl dehydrogenase', 'component_id': 4712, 'component_type': 'PROTEIN', 'relationship': 'SINGLE PROTEIN', 'target_component_synonyms': [{'component_synonym': 'lipdh', 'syn_type': 'GENE_SYMBOL'}, {'component_synonym': 'Dihydrolipoyl dehydrogenase', 'syn_type': 'UNIPROT'}, {'component_synonym': '1.8.1.4', 'syn_type': 'EC_NUMBER'}], 'target_component_xrefs': [{'xref_id': 'GO:0005737', 'xref_name': 'cytoplasm', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0005739', 'xref_name': 'mitochondrion', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0045252', 'xref_name': 'oxoglutarate dehydrogenase complex', 'xref_src_db': 'GoComponent'}, {'xref_id': 'GO:0000166', 'xref_name': 'nucleotide binding', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0004148', 'xref_name': 'dihydrolipoyl dehydrogenase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0016491', 'xref_name': 'oxidoreductase activity', 'xref_src_db': 'GoFunction'}, {'xref_id': 'GO:0016668', 'xref_name': 'oxidoreductase activity, acting on a sulfur group of donors, NAD(P) as acceptor', 'xr ...

# %%
#Convert query result to DataFrame and visualize
data = pd.DataFrame.from_dict(target_query) # Converting the query result in dict to a DataFrame
data # Displaying the DataFrame
# Out:
#                                     cross_references               organism  \
# 0  [{'xref_id': 'Q54A96', 'xref_name': None, 'xre...  Plasmodium falciparum
# 1  [{'xref_id': 'Q6KCB6', 'xref_name': None, 'xre...  Plasmodium falciparum
# 2                                                 []  Plasmodium falciparum
# 3  [{'xref_id': 'Q6VVP7', 'xref_name': None, 'xre...  Plasmodium falciparum
# 4                                                 []  Plasmodium falciparum
# 5                                                 []  Plasmodium falciparum
# 6  [{'xref_id': 'Q965D6', 'xref_name': None, 'xre...  Plasmodium falciparum
# 7  [{'xref_id': 'Q965D5', 'xref_name': None, 'xre...  Plasmodium falciparum
#
#                                   pref_name  score  species_group_flag  \
# 0              Dihydroorotate dehydrogenase   24.0               False
# 1               Dihydrolipoyl dehydrogenase    9.0               False
# 2                     Lactate dehydrogenase    9.0               False
# 3                      Malate dehydrogenase    9.0               False
# 4       Glucose-6-phosphate 1-dehydrogenase    8.0               False
# 5  Glyceraldehyde-3-phosphate dehydrogenase    8.0               False
# 6  3-oxoacyl-acyl-carrier protein reductase    2.0               False
# 7      Enoyl-acyl-carrier protein reductase    2.0               False
#
#   target_chembl_id                                  target_components  \
# 0       CHEMBL3486  [{'accession': 'Q54A96', 'component_descriptio...
# 1       CHEMBL6147  [{'accession': 'Q6KCB6', 'component_descriptio...
# 2       CHEMBL6071  [{'accession': 'Q0PJ46', 'component_descriptio...
# 3       CHEMBL6072  [{'accession': 'Q6VVP7', 'component_descriptio...
# 4    CHEMBL2169726  [{'accession': 'Q25856', 'component_descriptio...
# 5    CHEMBL3559677  [{'accession': 'Q8T6B1', 'component_descriptio...
# 6       CHEMBL4513  [{'accession': 'Q965D6', 'component_descriptio...
# 7       CHEMBL4150  [{'accession': 'Q965D5', 'component_descriptio...
#
#       target_type  tax_id
# 0  SINGLE PROTEIN    5833
# 1  SINGLE PROTEIN    5833
# 2  SINGLE PROTEIN    5833
# 3  SINGLE PROTEIN    5833
# 4  SINGLE PROTEIN    5833
# 5  SINGLE PROTEIN    5833
# 6  SINGLE PROTEIN    5833
# 7  SINGLE PROTEIN    5833

# %% [markdown]
# The first one (0th entry) is our target protein that is PfDHODH,and its id CHEMBL3486

# %%
## Extract the 'target_chembl_id' of the first row in the DataFrame as our target
our_target = data.iloc[0]['target_chembl_id'] # Extracting the 'target_chembl_id' of the first row in the DataFrame 
our_target # Displaying the 'target_chembl_id'
# Out:
# 'CHEMBL3486'

# %% [markdown]
# ##### __1.2 Retrieve bioactivity data of compounds  for the PfDHODH target__

# %%
target_activity = new_client.activity # For accessing activity in ChEMBL
target_activity # Displaying the data which in this case is a dictionary
# Out:
# [{'action_type': None, 'activity_comment': None, 'activity_id': 31863, 'activity_properties': [], 'assay_chembl_id': 'CHEMBL663853', 'assay_description': 'Inhibitory concentration against human DNA topoisomerase II, alpha mediated relaxation of pBR322; no measurable activity', 'assay_type': 'B', 'assay_variant_accession': None, 'assay_variant_mutation': None, 'bao_endpoint': 'BAO_0000190', 'bao_format': 'BAO_0000357', 'bao_label': 'single protein format', 'canonical_smiles': 'c1ccc(-c2nc3c(-c4nc5ccccc5o4)cccc3o2)cc1', 'data_validity_comment': None, 'data_validity_description': None, 'document_chembl_id': 'CHEMBL1137930', 'document_journal': 'Bioorg Med Chem Lett', 'document_year': 2004, 'ligand_efficiency': None, 'molecule_chembl_id': 'CHEMBL113081', 'molecule_pref_name': None, 'parent_molecule_chembl_id': 'CHEMBL113081', 'pchembl_value': None, 'potential_duplicate': 0, 'qudt_units': 'http://www.openphacts.org/units/Nanomolar', 'record_id': 206172, 'relation': '>', 'src_id': 1, 'standard_flag': 1, 'standard_relation': '>', 'standard_text_value': None, 'standard_type': 'IC50', 'standard_units': 'nM', 'standard_upper_value': None, 'standard_value': '100000.0', 'target_chembl_id': 'CHEMBL1806', 'target_organism': 'Homo sapiens', 'target_pref_name': 'DNA topoisomerase II alpha', 'target_tax_id': '9606', 'text_value': None, 'toid': None, 'type': 'IC50', 'units': 'uM', 'uo_units': 'UO_0000065', 'upper_value': None, 'value': '100.0'}, {'action_type': None, 'activity_comment': None, 'activity_id': 31864, 'activity_properties': [], 'assay_chembl_id': 'CHEMBL872937', 'assay_description': 'In vivo inhibitory activity against human Heparanase', 'assay_type': 'B', 'assay_variant_accession': None, 'assay_variant_mutation': None, 'bao_endpoint': 'BAO_0000190', 'bao_format': 'BAO_0000218', 'bao_label': 'organism-based format', 'canonical_smiles': 'Cc1ccc2oc(-c3cccc(N4C(=O)c5ccc(C(=O)O)cc5C4=O)c3)nc2c1', 'data_validity_comment': None, 'data_validity_description': None, 'document_chembl_id': 'CHEMBL1146658', 'document_journal': 'Bioorg Med Chem Lett', 'document_year': 2004, 'ligand_efficiency': {'bei': '14.06', 'le': '0.26', 'lle': '1.30', 'sei': '5.56'}, 'molecule_chembl_id': 'CHEMBL324340', 'molecule_pref_name': None, 'parent_molecule_chembl_id': 'CHEMBL324340', 'pchembl_value': '5.60', 'potential_duplicate': 0, 'qudt_units': 'http://www.openphacts.org/units/Nanomolar', 'record_id': 208970, 'relation': '=', 'src_id': 1, 'standard_flag': 1, 'standard_relation': '=', 'standard_text_value': None, 'standard_type': 'IC50', 'standard_units': 'nM', 'standard_upper_value': None, 'standard_value': '2500.0', 'target_chembl_id': 'CHEMBL3921', 'target_organism': 'Homo sapiens', 'target_pref_name': 'Heparanase', 'target_tax_id': '9606', 'text_value': None, 'toid': None, 'type': 'IC50', 'units': 'uM', 'uo_units': 'UO_0000065', 'upper_value': None, 'value': '2.5'}, {'action_type': None, 'activity_comment': None, 'activity_id': 31865, 'activity_properties': [], 'assay_chembl_id': 'CHEMBL693237', 'assay_description': 'In vivo concentration required against angiogenesis in human endothelial cells', 'assay_type': 'F', 'assay_variant_accession': None, 'assay_variant_mutation': None, 'bao_endpoint': 'BAO_0000190', 'bao_format': 'BAO_0000218', 'bao_label': 'organism-based format', 'canonical_smiles': 'Cc1ccc2oc(-c3cccc(N4C(=O)c5ccc(C(=O)O)cc5C4=O)c3)nc2c1', 'data_validity_comment': None, 'data_validity_description': None, 'document_chembl_id': 'CHEMBL1146658', 'document_journal': 'Bioorg Med Chem Lett', 'document_year': 2004, 'ligand_efficiency': None, 'molecule_chembl_id': 'CHEMBL324340', 'molecule_pref_name': None, 'parent_molecule_chembl_id': 'CHEMBL324340', 'pchembl_value': None, 'potential_duplicate': 0, 'qudt_units': 'http://www.openphacts.org/units/Nanomolar', 'record_id': 208970, 'relation': '>', 'src_id': 1, 'standard_flag': 1, 'standard_relation': '>', 'standard_text_value': None, 'standard_type': 'IC50', 'standard_units': 'nM', 'standard_upper_value': N ...

# %%
#Query the target activity data for our specific target protein and filter for standard type 'IC50'
target_query = target_activity.filter(target_chembl_id=our_target).filter(standard_type='IC50') 
target_query # Displaying the data which in this case is a dictionary
# Out:
# [{'action_type': None, 'activity_comment': None, 'activity_id': 1662473, 'activity_properties': [], 'assay_chembl_id': 'CHEMBL863916', 'assay_description': 'Binding affinity to Plasmodium falciparum DHODH', 'assay_type': 'B', 'assay_variant_accession': None, 'assay_variant_mutation': None, 'bao_endpoint': 'BAO_0000190', 'bao_format': 'BAO_0000357', 'bao_label': 'single protein format', 'canonical_smiles': 'CN(C(=O)c1ccc(-c2ccccc2)cc1)c1ccccc1C(=O)O', 'data_validity_comment': None, 'data_validity_description': None, 'document_chembl_id': 'CHEMBL1148537', 'document_journal': 'Bioorg Med Chem Lett', 'document_year': 2006, 'ligand_efficiency': {'bei': '13.19', 'le': '0.24', 'lle': '0.04', 'sei': '7.59'}, 'molecule_chembl_id': 'CHEMBL199572', 'molecule_pref_name': None, 'parent_molecule_chembl_id': 'CHEMBL199572', 'pchembl_value': '4.37', 'potential_duplicate': 0, 'qudt_units': 'http://www.openphacts.org/units/Nanomolar', 'record_id': 414629, 'relation': '=', 'src_id': 1, 'standard_flag': 1, 'standard_relation': '=', 'standard_text_value': None, 'standard_type': 'IC50', 'standard_units': 'nM', 'standard_upper_value': None, 'standard_value': '42600.0', 'target_chembl_id': 'CHEMBL3486', 'target_organism': 'Plasmodium falciparum', 'target_pref_name': 'Dihydroorotate dehydrogenase', 'target_tax_id': '5833', 'text_value': None, 'toid': None, 'type': 'IC50', 'units': 'uM', 'uo_units': 'UO_0000065', 'upper_value': None, 'value': '42.6'}, {'action_type': None, 'activity_comment': None, 'activity_id': 1662477, 'activity_properties': [], 'assay_chembl_id': 'CHEMBL863916', 'assay_description': 'Binding affinity to Plasmodium falciparum DHODH', 'assay_type': 'B', 'assay_variant_accession': None, 'assay_variant_mutation': None, 'bao_endpoint': 'BAO_0000190', 'bao_format': 'BAO_0000357', 'bao_label': 'single protein format', 'canonical_smiles': 'O=C(Nc1ccccc1C(=O)O)c1ccc2cc(Br)ccc2c1', 'data_validity_comment': 'Outside typical range', 'data_validity_description': 'Values for this activity type are unusually large/small, so may not be accurate', 'document_chembl_id': 'CHEMBL1148537', 'document_journal': 'Bioorg Med Chem Lett', 'document_year': 2006, 'ligand_efficiency': None, 'molecule_chembl_id': 'CHEMBL199574', 'molecule_pref_name': None, 'parent_molecule_chembl_id': 'CHEMBL199574', 'pchembl_value': None, 'potential_duplicate': 0, 'qudt_units': 'http://www.openphacts.org/units/Nanomolar', 'record_id': 414632, 'relation': '=', 'src_id': 1, 'standard_flag': 1, 'standard_relation': '=', 'standard_text_value': None, 'standard_type': 'IC50', 'standard_units': 'nM', 'standard_upper_value': None, 'standard_value': '142600.0', 'target_chembl_id': 'CHEMBL3486', 'target_organism': 'Plasmodium falciparum', 'target_pref_name': 'Dihydroorotate dehydrogenase', 'target_tax_id': '5833', 'text_value': None, 'toid': None, 'type': 'IC50', 'units': 'uM', 'uo_units': 'UO_0000065', 'upper_value': None, 'value': '142.6'}, {'action_type': None, 'activity_comment': None, 'activity_id': 1662479, 'activity_properties': [], 'assay_chembl_id': 'CHEMBL863916', 'assay_description': 'Binding affinity to Plasmodium falciparum DHODH', 'assay_type': 'B', 'assay_variant_accession': None, 'assay_variant_mutation': None, 'bao_endpoint': 'BAO_0000190', 'bao_format': 'BAO_0000357', 'bao_label': 'single protein format', 'canonical_smiles': 'CN(C(=O)c1ccc2cc(Br)ccc2c1)c1ccccc1C(=O)O', 'data_validity_comment': None, 'data_validity_description': None, 'document_chembl_id': 'CHEMBL1148537', 'document_journal': 'Bioorg Med Chem Lett', 'document_year': 2006, 'ligand_efficiency': {'bei': '10.49', 'le': '0.23', 'lle': '-0.55', 'sei': '6.99'}, 'molecule_chembl_id': 'CHEMBL372561', 'molecule_pref_name': None, 'parent_molecule_chembl_id': 'CHEMBL372561', 'pchembl_value': '4.03', 'potential_duplicate': 0, 'qudt_units': 'http://www.openphacts.org/units/Nanomolar', 'record_id': 414631, 'relation': '=', 'src_id': 1, 'standard_flag': 1, 'standard_relation': '=', 'standard_text_value': None, 'standard ...

# %%
## Convert the target query result to a pandas DataFrame for easier data manipulation and analysis
df = pd.DataFrame.from_dict(target_query)
df # Displaying the DataFrame
# Out:
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None      1662473                  []
# 1          None             None      1662477                  []
# 2          None             None      1662479                  []
# 3          None             None      1662481                  []
# 4          None             None      1662493                  []
# ..          ...              ...          ...                 ...
# 597        None             None     18951322                  []
# 598        None             None     18951323                  []
# 599        None             None     18951324                  []
# 600        None             None     19145102                  []
# 601        None             None     19145103                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL863916    Binding affinity to Plasmodium falciparum DHODH
# 1      CHEMBL863916    Binding affinity to Plasmodium falciparum DHODH
# 2      CHEMBL863916    Binding affinity to Plasmodium falciparum DHODH
# 3      CHEMBL863916    Binding affinity to Plasmodium falciparum DHODH
# 4      CHEMBL863916    Binding affinity to Plasmodium falciparum DHODH
# ..              ...                                                ...
# 597   CHEMBL4331522  Inhibition of Plasmodium falciparum recombinan...
# 598   CHEMBL4331522  Inhibition of Plasmodium falciparum recombinan...
# 599   CHEMBL4331522  Inhibition of Plasmodium falciparum recombinan...
# 600   CHEMBL4378107  Inhibition of Plasmodium falciparum DHODH expr...
# 601   CHEMBL4378107  Inhibition of Plasmodium falciparum DHODH expr...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            B                    None                   None  BAO_0000190
# 1            B                    None                   None  BAO_0000190
# 2            B                    None                   None  BAO_0000190
# 3            B                    None                   None  BAO_0000190
# 4            B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 597          B                    None                   None  BAO_0000190
# 598          B                    None                   None  BAO_0000190
# 599          B                    None                   None  BAO_0000190
# 600          B                    None                   None  BAO_0000190
# 601          B                    None                   None  BAO_0000190
#
#      ...        target_organism              target_pref_name target_tax_id  \
# 0    ...  Plasmodium falciparum  Dihydroorotate dehydrogenase          5833
# 1    ...  Plasmodium falciparum  Dihydroorotate dehydrogenase          5833
# 2    ...  Plasmodium falciparum  Dihydroorotate dehydrogenase          5833
# 3    ...  Plasmodium falciparum  Dihydroorotate dehydrogenase          5833
# 4    ...  Plasmodium falciparum  Dihydroorotate dehydrogenase          5833
# ..   ...                    ...                           ...           ...
# 597  ...  Plasmodium falciparum  Dihydroorotate dehydrogenase          5833
# 598  ...  Plasmodium falciparum  Dihydroorotate dehydrogenase          5833
# 599  ...  Plasmodium falciparum  Dihydroorotate dehydrogenase          5833
# 600  ...  Plasmodium falciparum  Dihydroorotate dehydrogenase          5833
# 601  ...  Plasmodium falciparum  Dihydroorotate dehydrogenase          5833
#
#     text_value  toid  type units    uo_units upper_value  value
# 0         None  None  IC50    uM  UO_0000065        None   42.6
# 1         None  None  IC50    uM  UO_0000065        None  142.6
# 2         None  None  IC50    uM  UO_0000065        None   93.4
# 3         None  None  IC50    uM  UO_0000065        None  153.5
# 4         None  None  IC50    uM  UO_0000065        None  200.0
# ..         ...   ...   ...   ...         ...         ...    ...
# 597       None  None  IC50    uM  UO_0000065        None  250.0
# 598       None  None  IC50    uM  UO_0000065        None  250.0
# 599       None  None  IC50    uM  UO_0000065        None  250.0
# 600       None  None  IC50    uM  UO_0000065        None   0.01
# 601       None  None  IC50    uM  UO_0000065        None   0.01
#
# [602 rows x 46 columns]

# %% [markdown]
# A total of 602 compounds, each with its potency (IC50) and chemical structure, etc, are available for the PfDHODH target. Let's visualize them below.

# %%
# Select and display only the 'standard_value', 'molecule_chembl_id', and 'canonical_smiles' columns from the DataFrame
df[['standard_value', 'molecule_chembl_id','canonical_smiles' ]]
# Out:
#     standard_value molecule_chembl_id  \
# 0          42600.0       CHEMBL199572
# 1         142600.0       CHEMBL199574
# 2          93400.0       CHEMBL372561
# 3         153500.0       CHEMBL370865
# 4         200000.0       CHEMBL199575
# ..             ...                ...
# 597       250000.0      CHEMBL4569109
# 598       250000.0      CHEMBL4568957
# 599       250000.0      CHEMBL4449622
# 600           10.0      CHEMBL1956285
# 601           10.0      CHEMBL4545127
#
#                                       canonical_smiles
# 0           CN(C(=O)c1ccc(-c2ccccc2)cc1)c1ccccc1C(=O)O
# 1               O=C(Nc1ccccc1C(=O)O)c1ccc2cc(Br)ccc2c1
# 2            CN(C(=O)c1ccc2cc(Br)ccc2c1)c1ccccc1C(=O)O
# 3              O=C(Nc1ccccc1C(=O)O)c1ccc(-c2ccccc2)cc1
# 4                CN(C(=O)c1ccc2ccccc2c1)c1ccccc1C(=O)O
# ..                                                 ...
# 597                Cn1nc(OCC2CC2)c(C(=O)O)c1COc1ccccc1
# 598             Cn1nc(OCc2ccccc2)c(C(=O)O)c1COc1ccccc1
# 599                      Cn1nc(O)c(C(N)=O)c1COc1ccccc1
# 600  Cc1cc(Nc2ccc(S(F)(F)(F)(F)F)cc2)n2nc(C(C)(F)F)...
# 601  Cc1cc(Nc2ccc(S(F)(F)(F)(F)F)c(F)c2)n2nc(C(C)(F...
#
# [602 rows x 3 columns]

# %% [markdown]
# ##### __Save the raw data to CSV file__

# %%
df.to_csv('../data/chembl_dataset/00_PfDHODH_raw_data.csv', index=False) # Save the DataFrame to a CSV file
